# %%
from sympy.abc import *
from sympy import expand

ㄱ = a * c - b * d
ㄴ = b * c + a * d
ㄷ = a + b
ㄹ = c + d

result = tuple(map(expand, (ㄱ * ㄷ, ㄱ * ㄹ, ㄴ * ㄷ, ㄴ * ㄹ)))

# %%
result[0]
# Out:
# a**2*c + a*b*c - a*b*d - b**2*d

# %%
result[1]
# Out:
# a*c**2 + a*c*d - b*c*d - b*d**2

# %%
result[2]
# Out:
# a**2*d + a*b*c + a*b*d + b**2*c

# %%
result[3]
# Out:
# a*c*d + a*d**2 + b*c**2 + b*c*d
