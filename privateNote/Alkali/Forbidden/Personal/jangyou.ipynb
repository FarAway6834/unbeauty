# %%
from sympy.abc import *

ㄱ = a * c - b * d
ㄴ = b * c + a * d
ㄷ = a + b
ㄹ = c + d

print(ㄱ * ㄷ, ㄱ * ㄹ, ㄴ * ㄷ, ㄴ * ㄹ)
# Out:
# (a + b)*(a*c - b*d) (c + d)*(a*c - b*d) (a + b)*(a*d + b*c) (c + d)*(a*d + b*c)
